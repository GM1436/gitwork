# %% [markdown]
# ## Git

# %%
Git is a free and open source distributed version control system

# %%
version control system: 
    
    ml_project_linear_reg_v1.0
    
    After 6 month data has changes
    
    Make New --- >> ml_project_linear_reg_v1.1 
                --->> 
        
    after 3 months change in pipeline --- >> Failed 
    
    Make a copy of older version  --- >>  ml_project_linear_reg_v1.2

# %% [markdown]
# ## git Arc

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Repo --- >> Project Folder

# %%
### Simple workflow of git

git init

git add file_name.txt

git commit -m "your msg"

# %%
git status -- >> To the status

# %% [markdown]
# ## Branch

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Merging the branches

# %%
git merge your branch_name

# %% [markdown]
# # github

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
github is software as service provided by microsoft.

# %%
git remote add oriin git_repo_url

git push origin main OR git push -u origin main
